# %% [raw]
# # 01. Import Libraries

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Import Data

# %%
# Path to main folder
path = r'C:\Users\jmacs\Documents\Career Foundry Tasks\01-2024 Instacart Basket Analysis'

# %%
# Importing ords_prods_merge dataframe
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_complete.pkl'))

# %%
ords_prods_merge.shape
# Out:
# (32404859, 18)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                   15.0         196                  1          1
# 2                   21.0         196                  1          1
# 3                   29.0         196                  1          1
# 4                   28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices    price_range_loc  \
# 0         Soda        77              7     9.0  Mid-range product
# 1         Soda        77              7     9.0  Mid-range product
# 2         Soda        77              7     9.0  Mid-range product
# 3         Soda        77              7     9.0  Mid-range product
# 4         Soda        77              7     9.0  Mid-range product
#
#       busiest_day busiest_period_of_day  max_order  loyalty_flag
# 0  Regularly busy        Average Orders         10  New customer
# 1      Least busy        Average Orders         10  New customer
# 2      Least busy           Most Orders         10  New customer
# 3      Least busy        Average Orders         10  New customer
# 4      Least busy           Most Orders         10  New customer

# %% [markdown]
# # 03. Tasks

# %%
# grouping by department id and then aggregating by order number for entire dataframe
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# 21 is in the 'missing' department, meaning we can't tell what department the itme belongs to. Perhaps instacart needs to
# re-evaluate their labels for their items?
#
# The next top 2 are 10 'bulk' department and 18 'babies' department.

# %%
# grouping by loyalty_flag and then aggregating by prices
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# Surprisingly, loyal customers on average spend less per order than new and regular customers.
# New customers are spending more than loyal and regular customers.

# %%
# split data into 'user_id' group, 
# apply transform to 'prices' to generate average spending for each user, 
# and create new column 'avg_order_price'

ords_prods_merge['avg_order_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)
# Out:
# C:\Users\jmacs\AppData\Local\Temp\ipykernel_3468\46790144.py:5: FutureWarning: The provided callable <function mean at 0x00000150231428E0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ords_prods_merge['avg_order_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                   15.0         196                  1          1
# 2                   21.0         196                  1          1
# 3                   29.0         196                  1          1
# 4                   28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices    price_range_loc  \
# 0         Soda        77              7     9.0  Mid-range product
# 1         Soda        77              7     9.0  Mid-range product
# 2         Soda        77              7     9.0  Mid-range product
# 3         Soda        77              7     9.0  Mid-range product
# 4         Soda        77              7     9.0  Mid-range product
#
#       busiest_day busiest_period_of_day  max_order  loyalty_flag  \
# 0  Regularly busy        Average Orders         10  New customer
# 1      Least busy        Average Orders         10  New customer
# 2      Least busy           Most Orders         10  New customer
# 3      Least busy        Average Orders         10  New customer
# 4      Least busy           Most Orders         10  New customer
#
#    avg_order_price
# 0         6.367797
# 1         6.367797
# 2         6.367797
# 3         6.367797
# 4         6.367797

# %%
# setting the flags for high spender and low spender

ords_prods_merge.loc[ords_prods_merge['avg_order_price'] >= 10, 'spending_flag'] = 'High Spender'

# %%
ords_prods_merge.loc[ords_prods_merge['avg_order_price'] < 10, 'spending_flag'] = 'Low Spender'

# %%
# checking the value counts of spending flag
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# spending_flag
# Low Spender     31770614
# High Spender      634245
# Name: count, dtype: int64

# %%
# limiting output of head function to check columns using df['column']
ords_prods_merge[['user_id', 'spending_flag', 'avg_order_price']].head(60)
# Out:
#     user_id spending_flag  avg_order_price
# 0         1   Low Spender         6.367797
# 1         1   Low Spender         6.367797
# 2         1   Low Spender         6.367797
# 3         1   Low Spender         6.367797
# 4         1   Low Spender         6.367797
# 5         1   Low Spender         6.367797
# 6         1   Low Spender         6.367797
# 7         1   Low Spender         6.367797
# 8         1   Low Spender         6.367797
# 9         1   Low Spender         6.367797
# 10       15   Low Spender         3.980556
# 11       15   Low Spender         3.980556
# 12       15   Low Spender         3.980556
# 13       15   Low Spender         3.980556
# 14       15   Low Spender         3.980556
# 15       19   Low Spender         8.372059
# 16       19   Low Spender         8.372059
# 17       19   Low Spender         8.372059
# 18       21   Low Spender         7.012683
# 19       31   Low Spender         8.137793
# 20       31   Low Spender         8.137793
# 21       43   Low Spender         7.444898
# 22       43   Low Spender         7.444898
# 23       52   Low Spender         6.356287
# 24       52   Low Spender         6.356287
# 25       52   Low Spender         6.356287
# 26       52   Low Spender         6.356287
# 27       52   Low Spender         6.356287
# 28       52   Low Spender         6.356287
# 29       52   Low Spender         6.356287
# 30       52   Low Spender         6.356287
# 31       52   Low Spender         6.356287
# 32       52   Low Spender         6.356287
# 33       52   Low Spender         6.356287
# 34       52   Low Spender         6.356287
# 35       52   Low Spender         6.356287
# 36       52   Low Spender         6.356287
# 37       67   Low Spender         7.656790
# 38       67   Low Spender         7.656790
# 39       67   Low Spender         7.656790
# 40       67   Low Spender         7.656790
# 41       67   Low Spender         7.656790
# 42       67   Low Spender         7.656790
# 43       67   Low Spender         7.656790
# 44       67   Low Spender         7.656790
# 45       67   Low Spender         7.656790
# 46       67   Low Spender         7.656790
# 47       67   Low Spender         7.656790
# 48       67   Low Spender         7.656790
# 49       67   Low Spender         7.656790
# 50       67   Low Spender         7.656790
# 51       67   Low Spender         7.656790
# 52       67   Low Spender         7.656790
# 53       67   Low Spender         7.656790
# 54       67   Low Spender         7.656790
# 55       67   Low Spender         7.656790
# 56       81   Low Spender         8.165385
# 57       81   Low Spender         8.165385
# 58       82   Low Spender         6.441221
# 59       82   Low Spender         6.441221

# %%
# split data into 'user_id' group, 
# apply transform to 'days_since_last_order' to generate median days since last order, 
# and create new column 'avg_days_since_last_order'

ords_prods_merge['avg_days_since_last_order'] = ords_prods_merge.groupby(['user_id'])['days_since_last_order'].transform(np.mean)
# Out:
# C:\Users\jmacs\AppData\Local\Temp\ipykernel_3468\2749981782.py:5: FutureWarning: The provided callable <function mean at 0x00000150231428E0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ords_prods_merge['avg_days_since_last_order'] = ords_prods_merge.groupby(['user_id'])['days_since_last_order'].transform(np.mean)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                   15.0         196                  1          1
# 2                   21.0         196                  1          1
# 3                   29.0         196                  1          1
# 4                   28.0         196                  1          1
#
#   product_name  ...  department_id  prices    price_range_loc     busiest_day  \
# 0         Soda  ...              7     9.0  Mid-range product  Regularly busy
# 1         Soda  ...              7     9.0  Mid-range product      Least busy
# 2         Soda  ...              7     9.0  Mid-range product      Least busy
# 3         Soda  ...              7     9.0  Mid-range product      Least busy
# 4         Soda  ...              7     9.0  Mid-range product      Least busy
#
#   busiest_period_of_day max_order  loyalty_flag avg_order_price  \
# 0        Average Orders        10  New customer        6.367797
# 1        Average Orders        10  New customer        6.367797
# 2           Most Orders        10  New customer        6.367797
# 3        Average Orders        10  New customer        6.367797
# 4           Most Orders        10  New customer        6.367797
#
#    spending_flag avg_days_since_last_order
# 0    Low Spender                 20.259259
# 1    Low Spender                 20.259259
# 2    Low Spender                 20.259259
# 3    Low Spender                 20.259259
# 4    Low Spender                 20.259259
#
# [5 rows x 21 columns]

# %%
# setting the flags for frequent, regular, non frequent customer

ords_prods_merge.loc[ords_prods_merge['avg_days_since_last_order'] <= 10, 'frequency_flag'] = 'Frequent Customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['avg_days_since_last_order'] >10) & (ords_prods_merge['avg_days_since_last_order'] <=20), 'frequency_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['avg_days_since_last_order'] > 20, 'frequency_flag'] = 'Non-frequent customer'

# %%
# checking the value counts of frequency flag
ords_prods_merge['frequency_flag'].value_counts(dropna = False)
# Out:
# frequency_flag
# Frequent Customer        16468582
# Regular customer         12521159
# Non-frequent customer     3415113
# nan                             5
# Name: count, dtype: int64

# %%
# creating a subset with the rows of missing values from products
df_nan = ords_prods_merge[ords_prods_merge['avg_days_since_last_order'].isnull() == True]

# %%
df_nan # I find this odd that there are 5 nulls and they all belong to this one user, they may have never placed another order again?
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 13645692    895835   159838             1                   0
# 17251990    895835   159838             1                   0
# 17622767    895835   159838             1                   0
# 24138593    895835   159838             1                   0
# 25880002    895835   159838             1                   0
#
#           order_hour_of_day  days_since_last_order  product_id  \
# 13645692                 17                    NaN       10749
# 17251990                 17                    NaN       33401
# 17622767                 17                    NaN       23695
# 24138593                 17                    NaN       21334
# 25880002                 17                    NaN       22198
#
#           add_to_cart_order  reordered  \
# 13645692                  3          0
# 17251990                  6          0
# 17622767                  2          0
# 24138593                  5          0
# 25880002                  1          0
#
#                                                product_name  ...  prices  \
# 13645692                            Organic Red Bell Pepper  ...     5.7
# 17251990                               Goat Cheese Crumbles  ...    14.8
# 17622767                           California Veggie Burger  ...     4.7
# 24138593                              Organic Peeled Garlic  ...    10.2
# 25880002  4X Ultra Concentrated Natural Laundry Detergen...  ...     1.7
#
#             price_range_loc  busiest_day busiest_period_of_day max_order  \
# 13645692  Mid-range product  Busiest day        Average Orders         1
# 17251990  Mid-range product  Busiest day        Average Orders         1
# 17622767  Low-range product  Busiest day        Average Orders         1
# 24138593  Mid-range product  Busiest day        Average Orders         1
# 25880002  Low-range product  Busiest day        Average Orders         1
#
#           loyalty_flag  avg_order_price spending_flag  \
# 13645692  New customer             7.42   Low Spender
# 17251990  New customer             7.42   Low Spender
# 17622767  New customer             7.42   Low Spender
# 24138593  New customer             7.42   Low Spender
# 25880002  New customer             7.42   Low Spender
#
#           avg_days_since_last_order frequency_flag
# 13645692                        NaN            nan
# 17251990                        NaN            nan
# 17622767                        NaN            nan
# 24138593                        NaN            nan
# 25880002                        NaN            nan
#
# [5 rows x 22 columns]

# %%
# checking dataframe for missing values
ords_prods_merge.isnull().sum()
# Out:
# order_id                           0
# user_id                            0
# order_number                       0
# orders_day_of_week                 0
# order_hour_of_day                  0
# days_since_last_order        2076096
# product_id                         0
# add_to_cart_order                  0
# reordered                          0
# product_name                       0
# aisle_id                           0
# department_id                      0
# prices                             0
# price_range_loc                    0
# busiest_day                        0
# busiest_period_of_day              0
# max_order                          0
# loyalty_flag                       0
# avg_order_price                    0
# spending_flag                      0
# avg_days_since_last_order          5
# frequency_flag                     0
# dtype: int64

# %%
# limiting output of head function to check columns using df['column']
ords_prods_merge[['user_id', 'frequency_flag', 'avg_days_since_last_order']].head(60)
# Out:
#     user_id         frequency_flag  avg_days_since_last_order
# 0         1  Non-frequent customer                  20.259259
# 1         1  Non-frequent customer                  20.259259
# 2         1  Non-frequent customer                  20.259259
# 3         1  Non-frequent customer                  20.259259
# 4         1  Non-frequent customer                  20.259259
# 5         1  Non-frequent customer                  20.259259
# 6         1  Non-frequent customer                  20.259259
# 7         1  Non-frequent customer                  20.259259
# 8         1  Non-frequent customer                  20.259259
# 9         1  Non-frequent customer                  20.259259
# 10       15       Regular customer                  11.029412
# 11       15       Regular customer                  11.029412
# 12       15       Regular customer                  11.029412
# 13       15       Regular customer                  11.029412
# 14       15       Regular customer                  11.029412
# 15       19      Frequent Customer                   8.040698
# 16       19      Frequent Customer                   8.040698
# 17       19      Frequent Customer                   8.040698
# 18       21       Regular customer                  10.055000
# 19       31      Frequent Customer                   6.073427
# 20       31      Frequent Customer                   6.073427
# 21       43       Regular customer                  10.549296
# 22       43       Regular customer                  10.549296
# 23       52      Frequent Customer                   9.155280
# 24       52      Frequent Customer                   9.155280
# 25       52      Frequent Customer                   9.155280
# 26       52      Frequent Customer                   9.155280
# 27       52      Frequent Customer                   9.155280
# 28       52      Frequent Customer                   9.155280
# 29       52      Frequent Customer                   9.155280
# 30       52      Frequent Customer                   9.155280
# 31       52      Frequent Customer                   9.155280
# 32       52      Frequent Customer                   9.155280
# 33       52      Frequent Customer                   9.155280
# 34       52      Frequent Customer                   9.155280
# 35       52      Frequent Customer                   9.155280
# 36       52      Frequent Customer                   9.155280
# 37       67      Frequent Customer                   7.714286
# 38       67      Frequent Customer                   7.714286
# 39       67      Frequent Customer                   7.714286
# 40       67      Frequent Customer                   7.714286
# 41       67      Frequent Customer                   7.714286
# 42       67      Frequent Customer                   7.714286
# 43       67      Frequent Customer                   7.714286
# 44       67      Frequent Customer                   7.714286
# 45       67      Frequent Customer                   7.714286
# 46       67      Frequent Customer                   7.714286
# 47       67      Frequent Customer                   7.714286
# 48       67      Frequent Customer                   7.714286
# 49       67      Frequent Customer                   7.714286
# 50       67      Frequent Customer                   7.714286
# 51       67      Frequent Customer                   7.714286
# 52       67      Frequent Customer                   7.714286
# 53       67      Frequent Customer                   7.714286
# 54       67      Frequent Customer                   7.714286
# 55       67      Frequent Customer                   7.714286
# 56       81  Non-frequent customer                  26.086957
# 57       81  Non-frequent customer                  26.086957
# 58       82       Regular customer                  12.188525
# 59       82       Regular customer                  12.188525

# %%
# exporting orders_products_merge in pickle format
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_complete.pkl'))
